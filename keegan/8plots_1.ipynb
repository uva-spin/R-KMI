Epoch 499: Loss: 10638311.000 val_Loss: 30786992.000 ReH_mape: 22.54574 ReE_mape: 171.06160 ReHt_mape: 168.67363 ReEt_mape: 102.30162 ImH_mape: 100.02306 ImE_mape: 1103396.62500 ImHt_mape: 100.18983 ImEt_mape: 1423162.75000 total_mape: 315903.00000
Epoch 499: Loss: 10699651.000 val_Loss: 31122322.000 ReH_mape: 22.05080 ReE_mape: 172.74101 ReHt_mape: 170.10542 ReEt_mape: 102.32635 ImH_mape: 100.17686 ImE_mape: 2160243.50000 ImHt_mape: 99.70042 ImEt_mape: 23167280.00000 total_mape: 3166024.00000

"""
# Split the data into lines 
lines = data.strip().split('\n')

# Initialize an empty list to store the rows
rows = []

# Process each line
for line in lines:
    # Split the line into parts
    parts = line.split()
    # Extract the values
    epoch = parts[1].strip(':')
    loss = float(parts[3])
    val_loss = float(parts[5])
    #f_rmse = float(parts[7])
    reh_mape = float(parts[7])
    ree_mape = float(parts[9])
    reht_mape = float(parts[11])
    reet_mape = float(parts[13])
    imh_mape = float(parts[15])
    ime_mape = float(parts[17])
    imht_mape = float(parts[19])
    imet_mape = float(parts[21])
    
    #dvcs_mape = float(parts[15])
    #total_mape = float(parts[17])
    # Append the row to the li
    rows.append([epoch, loss, val_loss, reh_mape, ree_mape, reht_mape, reet_mape, imh_mape, ime_mape, imht_mape, imet_mape ])

# Create the DataFrame
df = pd.DataFrame(rows, columns=['Epoch', 'Loss', 'val_Loss', 'ReH_error', 'ReE_error', 'ReHt_error', 'ReEt_error', 'ImH_error', 'ImE_error', 'ImHt_error', 'ImEt_error'])
# Create box plots for Re values
plt.figure(figsize=(8, 6))
df.boxplot(column=['ReH_error', 'ReE_error', 'ReHt_error', 'ReEt_error'])
plt.title('Box Plots for ReH, ReE, ReHt, ReEt')
plt.ylabel('Values')
plt.show()

# Create box plots for Im values
plt.figure(figsize=(8, 6) )
#df.boxplot(column=['ImH_error', 'ImE_error', 'ImHt_error', 'ImEt_error'])
df.boxplot(column=['ImH_error', 'ImHt_error'])
plt.title('Box Plots for ImH, ImE, ImHt, ImEt')
plt.ylabel('Values')
plt.show()

# %%
#first run, all three cffs. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
fig_width = 3.385
#fig_height = 2.75 
fig_height = 8 
fontsize = 11 
fontfamily = 'sans-serif'

import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('8_fulllT2.csv')

# Remove non-numerical rows
df = df.apply(pd.to_numeric, errors='coerce')
df = df.dropna()
def normalize(QQ, xB, t):
    QQ_norm = -1 + 2 * (QQ / 10) 
    xB_norm = -1 + 2 * (xB / 0.8)
    t_norm = -1 + 2 * ((t + 2) / 2 )
    return QQ_norm, xB_norm, t_norm

def find_matching_rows(df, qq, xb, t):
    #qqq, xbb, ttt = normalize(qq, xb, t)
    # print(qqq)
    
    return df[(df['QQ'] == qq) & (df['xB'] == xb) & (df['t'] == t)]
datafile = "8shorttA.csv"
def get_data():
    df = pd.read_csv(datafile, dtype=np.float32)
    return df
def filter_unique_sets(df):
    # Drop duplicate rows based on the first column
    unique_rows = df.drop_duplicates(subset=df.columns[0])
    return unique_rows 
ddf = get_data()
ddf = filter_unique_sets(ddf)


# print(df['QQ'][0])
 
norm_Q, norm_xb, norm_t =  normalize(ddf['QQ'], ddf['xB'], ddf['t'])
ddf['QQ'] = norm_Q 
ddf['xB'] = norm_xb
ddf['t'] = norm_t 

#print(find_matching_rows(ddf, df['QQ'][0], df['x_B'][0], df['t'][0]))
matching_first_row = find_matching_rows(ddf, df['QQ'][0], df['x_B'][0], df['t'][0])
matching_second_row = find_matching_rows(ddf, df['QQ'][1], df['x_B'][1], df['t'][1])
matching_third_row = find_matching_rows(ddf, df['QQ'][2], df['x_B'][2], df['t'][2])
#

# Extract the matching values of ReH, ReE, ReHt
matching_ReH_values = pd.concat([matching_first_row['ReH'], matching_second_row['ReH'], matching_third_row['ReH']]).to_numpy()
matching_ReE_values = pd.concat([matching_first_row['ReE'], matching_second_row['ReE'], matching_third_row['ReE']]).to_numpy()
matching_ReHt_values = pd.concat([matching_first_row['ReHt'], matching_second_row['ReHt'], matching_third_row['ReHt']]).to_numpy()

# Extract the matching values of ReEt, ImH, ImE
matching_ReEt_values = pd.concat([matching_first_row['ReEt'], matching_second_row['ReEt'], matching_third_row['ReEt']]).to_numpy()
matching_ImH_values = pd.concat([matching_first_row['ImH'], matching_second_row['ImH'], matching_third_row['ImH']]).to_numpy()
matching_ImE_values = pd.concat([matching_first_row['ImE'], matching_second_row['ImE'], matching_third_row['ImE']]).to_numpy()
# Extract the matching values of ImHt and ImEt
matching_ImHt_values = pd.concat([matching_first_row['ImHt'], matching_second_row['ImHt'], matching_third_row['ImHt']]).to_numpy()
matching_ImEt_values = pd.concat([matching_first_row['ImEt'], matching_second_row['ImEt'], matching_third_row['ImEt']]).to_numpy()

# Get the values of the first three ReH, ReE, and ReHt in each cycle
first_three_ReH_values = df['ReH_results'][::69].tolist()
second_three_ReH_values = df['ReH_results'][1::69].tolist()
third_three_ReH_values = df['ReH_results'][2::69].tolist()

first_three_ReE_values = df['ReE_results'][::69].tolist()
second_three_ReE_values = df['ReE_results'][1::69].tolist()
third_three_ReE_values = df['ReE_results'][2::69].tolist()

first_three_ReHt_values = df['ReHt_results'][::69].tolist()
second_three_ReHt_values = df['ReHt_results'][1::69].tolist()
third_three_ReHt_values = df['ReHt_results'][2::69].tolist()

# Get the values of the first three ReEt, ImH, and ImE in each cycle
first_three_ReEt_values = df['ReEt_results'][::69].tolist()
second_three_ReEt_values = df['ReEt_results'][1::69].tolist()
third_three_ReEt_values = df['ReEt_results'][2::69].tolist()

first_three_ImH_values = df['ImH_results'][::69].tolist()
second_three_ImH_values = df['ImH_results'][1::69].tolist()
third_three_ImH_values = df['ImH_results'][2::69].tolist()

first_three_ImE_values = df['ImE_results'][::69].tolist()
second_three_ImE_values = df['ImE_results'][1::69].tolist()
third_three_ImE_values = df['ImE_results'][2::69].tolist()


# Get the values of the first three ImHt and ImEt in each cycle
first_three_ImHt_values = df['ImHt_results'][::69].tolist()
second_three_ImHt_values = df['ImHt_results'][1::69].tolist()
third_three_ImHt_values = df['ImHt_results'][2::69].tolist()

first_three_ImEt_values = df['ImEt_results'][::69].tolist()
second_three_ImEt_values = df['ImEt_results'][1::69].tolist()
third_three_ImEt_values = df['ImEt_results'][2::69].tolist()


# Calculate the means
mean_first_ReH = sum(first_three_ReH_values) / len(first_three_ReH_values)
mean_second_ReH = sum(second_three_ReH_values) / len(second_three_ReH_values)
mean_third_ReH = sum(third_three_ReH_values) / len(third_three_ReH_values)

mean_first_ReE = sum(first_three_ReE_values) / len(first_three_ReE_values)
mean_second_ReE = sum(second_three_ReE_values) / len(second_three_ReE_values)
mean_third_ReE = sum(third_three_ReE_values) / len(third_three_ReE_values)

mean_first_ReHt = sum(first_three_ReHt_values) / len(first_three_ReHt_values)
mean_second_ReHt = sum(second_three_ReHt_values) / len(second_three_ReHt_values)
mean_third_ReHt = sum(third_three_ReHt_values) / len(third_three_ReHt_values)

mean_first_ReEt = sum(first_three_ReEt_values) / len(first_three_ReEt_values)
mean_second_ReEt = sum(second_three_ReEt_values) / len(second_three_ReEt_values)
mean_third_ReEt = sum(third_three_ReEt_values) / len(third_three_ReEt_values)

mean_first_ImH = sum(first_three_ImH_values) / len(first_three_ImH_values)
mean_second_ImH = sum(second_three_ImH_values) / len(second_three_ImH_values)
mean_third_ImH = sum(third_three_ImH_values) / len(third_three_ImH_values)

mean_first_ImE = sum(first_three_ImE_values) / len(first_three_ImE_values)
mean_second_ImE = sum(second_three_ImE_values) / len(second_three_ImE_values)
mean_third_ImE = sum(third_three_ImE_values) / len(third_three_ImE_values)

mean_first_ImHt = sum(first_three_ImHt_values) / len(first_three_ImHt_values)
mean_second_ImHt = sum(second_three_ImHt_values) / len(second_three_ImHt_values)
mean_third_ImHt = sum(third_three_ImHt_values) / len(third_three_ImHt_values)

mean_first_ImEt = sum(first_three_ImEt_values) / len(first_three_ImEt_values)
mean_second_ImEt = sum(second_three_ImEt_values) / len(second_three_ImEt_values)
mean_third_ImEt = sum(third_three_ImEt_values) / len(third_three_ImEt_values)


# Create a figure with multiple subplots
#plt.figure(figsize=(15, 15))

# ReH histogram
#plt.subplot(3, 1, 1)
plt.figure(0)
plt.hist(first_three_ReH_values, bins=10, alpha=1, label='First ReH', color='blue', edgecolor='black')
plt.hist(second_three_ReH_values, bins=10, alpha=0.75, label='Second ReH', color='green', edgecolor='black')
plt.hist(third_three_ReH_values, bins=10, alpha=0.5, label='Third ReH', color='red', edgecolor='black')
plt.axvline(mean_first_ReH, color='blue', linestyle='dashed', linewidth=2, label=f'First ReH Mean: {mean_first_ReH:.2f}')
plt.axvline(mean_second_ReH, color='green', linestyle='dashed', linewidth=2, label=f'Second ReH Mean: {mean_second_ReH:.2f}')
plt.axvline(mean_third_ReH, color='red', linestyle='dashed', linewidth=2, label=f'Third ReH Mean: {mean_third_ReH:.2f}')
plt.axvline(matching_ReH_values[0], color='blue',  linewidth=2 )
plt.axvline(matching_ReH_values[1], color='green',  linewidth=2 )
plt.axvline(matching_ReH_values[2], color='red',  linewidth=2 )
plt.title('Histogram of First Three ReH Values, first')
plt.xlabel('ReH')
plt.ylabel('Frequency')
#plt.legend()

# ReE histogram
#plt.subplot(3, 1, 2)
plt.figure(1)
plt.hist(first_three_ReE_values, bins=10, alpha=0.5, label='First ReE', color='blue', edgecolor='black')
plt.hist(second_three_ReE_values, bins=10, alpha=0.5, label='Second ReE', color='green', edgecolor='black')
plt.hist(third_three_ReE_values, bins=10, alpha=0.5, label='Third ReE', color='red', edgecolor='black')
plt.axvline(mean_first_ReE, color='blue', linestyle='dashed', linewidth=2, label=f'First ReE Mean: {mean_first_ReE:.2f}')
plt.axvline(mean_second_ReE, color='green', linestyle='dashed', linewidth=2, label=f'Second ReE Mean: {mean_second_ReE:.2f}')
plt.axvline(mean_third_ReE, color='red', linestyle='dashed', linewidth=2, label=f'Third ReE Mean: {mean_third_ReE:.2f}')
plt.axvline(matching_ReE_values[0], color='blue',  linewidth=2 )
plt.axvline(matching_ReE_values[1], color='green',  linewidth=2 )
plt.axvline(matching_ReE_values[2], color='red',  linewidth=2 )
plt.title('Histogram of First Three ReE Values, first')
plt.xlabel('ReE')
plt.ylabel('Frequency')
#plt.legend()

# ReHt histogram
#plt.subplot(3, 1, 3)
plt.figure(2)
plt.hist(first_three_ReHt_values, bins=10, alpha=0.5, label='First ReHt', color='blue', edgecolor='black')
plt.hist(second_three_ReHt_values, bins=10, alpha=0.5, label='Second ReHt', color='green', edgecolor='black')
plt.hist(third_three_ReHt_values, bins=10, alpha=0.5, label='Third ReHt', color='red', edgecolor='black')
plt.axvline(mean_first_ReHt, color='blue', linestyle='dashed', linewidth=2, label=f'First ReHt Mean: {mean_first_ReHt:.2f}')
plt.axvline(mean_second_ReHt, color='green', linestyle='dashed', linewidth=2, label=f'Second ReHt Mean: {mean_second_ReHt:.2f}')
plt.axvline(mean_third_ReHt, color='red', linestyle='dashed', linewidth=2, label=f'Third ReHt Mean: {mean_third_ReHt:.2f}') 
plt.axvline(matching_ReHt_values[0], color='blue',  linewidth=2 )
plt.axvline(matching_ReHt_values[1], color='green',  linewidth=2 )
plt.axvline(matching_ReHt_values[2], color='red',  linewidth=2 )
plt.title('Histogram of First Three ReHt Values, first')
plt.xlabel('ReHt')
plt.ylabel('Frequency')
#plt.legend()

plt.figure(3)
plt.hist(first_three_ReEt_values, bins=10, alpha=1, label='First ReEt', color='blue', edgecolor='black')
plt.hist(second_three_ReEt_values, bins=10, alpha=0.6, label='Second ReEt', color='green', edgecolor='black')
plt.hist(third_three_ReEt_values, bins=10, alpha=0.5, label='Third ReEt', color='red', edgecolor='black')
plt.axvline(mean_first_ReEt, color='blue', linestyle='dashed', linewidth=2, label=f'First ReEt Mean: {mean_first_ReEt:.2f}')
plt.axvline(mean_second_ReEt, color='green', linestyle='dashed', linewidth=2, label=f'Second ReEt Mean: {mean_second_ReEt:.2f}')
plt.axvline(mean_third_ReEt, color='red', linestyle='dashed', linewidth=2, label=f'Third ReEt Mean: {mean_third_ReEt:.2f}')
plt.axvline(matching_ReEt_values[0], color='blue', linewidth=2)
plt.axvline(matching_ReEt_values[1], color='green', linewidth=2)
plt.axvline(matching_ReEt_values[2], color='red', linewidth=2)
plt.title('Histogram of First Three ReEt Values, first')
plt.xlabel('ReEt')
plt.ylabel('Frequency')
#plt.legend()

# ImH histogram
#plt.subplot(3, 1, 2)
plt.figure(4)
plt.hist(first_three_ImH_values, bins=10, alpha=0.5, label='First ImH', color='blue', edgecolor='black')
plt.hist(second_three_ImH_values, bins=10, alpha=0.5, label='Second ImH', color='green', edgecolor='black')
plt.hist(third_three_ImH_values, bins=10, alpha=0.5, label='Third ImH', color='red', edgecolor='black')
plt.axvline(mean_first_ImH, color='blue', linestyle='dashed', linewidth=2, label=f'First ImH Mean: {mean_first_ImH:.2f}')
plt.axvline(mean_second_ImH, color='green', linestyle='dashed', linewidth=2, label=f'Second ImH Mean: {mean_second_ImH:.2f}')
plt.axvline(mean_third_ImH, color='red', linestyle='dashed', linewidth=2, label=f'Third ImH Mean: {mean_third_ImH:.2f}')
plt.axvline(matching_ImH_values[0], color='blue', linewidth=2)
plt.axvline(matching_ImH_values[1], color='green', linewidth=2)
plt.axvline(matching_ImH_values[2], color='red', linewidth=2)
plt.title('Histogram of First Three ImH Values, first')
plt.xlabel('ImH')
plt.ylabel('Frequency')
#plt.legend()

# ImE histogram
#plt.subplot(3, 1, 3)
plt.figure(5)
plt.hist(first_three_ImE_values, bins=10, alpha=1, label='First ImE', color='blue', edgecolor='black')
plt.hist(second_three_ImE_values, bins=10, alpha=0.5, label='Second ImE', color='green', edgecolor='black')
plt.hist(third_three_ImE_values, bins=10, alpha=0.5, label='Third ImE', color='red', edgecolor='black')
plt.axvline(mean_first_ImE, color='blue', linestyle='dashed', linewidth=2, label=f'First ImE Mean: {mean_first_ImE:.2f}')
plt.axvline(mean_second_ImE, color='green', linestyle='dashed', linewidth=2, label=f'Second ImE Mean: {mean_second_ImE:.2f}')
plt.axvline(mean_third_ImE, color='red', linestyle='dashed', linewidth=2, label=f'Third ImE Mean: {mean_third_ImE:.2f}')
plt.axvline(matching_ImE_values[0], color='blue', linewidth=2)
plt.axvline(matching_ImE_values[1], color='green', linewidth=2)
plt.axvline(matching_ImE_values[2], color='red', linewidth=2)
plt.title('Histogram of First Three ImE Values, first')
plt.xlabel('ImE')
plt.ylabel('Frequency')

# ImHt histogram
#plt.subplot(3, 1, 2)
plt.figure(6)
plt.hist(first_three_ImHt_values, bins=10, alpha=0.5, label='First ImHt', color='blue', edgecolor='black')
plt.hist(second_three_ImHt_values, bins=10, alpha=0.5, label='Second ImHt', color='green', edgecolor='black')
plt.hist(third_three_ImHt_values, bins=10, alpha=0.5, label='Third ImHt', color='red', edgecolor='black')
plt.axvline(mean_first_ImHt, color='blue', linestyle='dashed', linewidth=2, label=f'First ImHt Mean: {mean_first_ImHt:.2f}')
plt.axvline(mean_second_ImHt, color='green', linestyle='dashed', linewidth=2, label=f'Second ImHt Mean: {mean_second_ImHt:.2f}')
plt.axvline(mean_third_ImHt, color='red', linestyle='dashed', linewidth=2, label=f'Third ImHt Mean: {mean_third_ImHt:.2f}')
plt.axvline(matching_ImHt_values[0], color='blue', linewidth=2)
plt.axvline(matching_ImHt_values[1], color='green', linewidth=2)
plt.axvline(matching_ImHt_values[2], color='red', linewidth=2)
plt.title('Histogram of First Three ImHt Values, first')
plt.xlabel('ImHt')
plt.ylabel('Frequency')
#plt.legend()

# ImEt histogram
#plt.subplot(3, 1, 3)
plt.figure(7)
plt.hist(first_three_ImEt_values, bins=10, alpha=0.5, label='First ImEt', color='blue', edgecolor='black')
plt.hist(second_three_ImEt_values, bins=10, alpha=0.5, label='Second ImEt', color='green', edgecolor='black')
plt.hist(third_three_ImEt_values, bins=10, alpha=0.5, label='Third ImEt', color='red', edgecolor='black')
plt.axvline(mean_first_ImEt, color='blue', linestyle='dashed', linewidth=2, label=f'First ImEt Mean: {mean_first_ImEt:.2f}')
plt.axvline(mean_second_ImEt, color='green', linestyle='dashed', linewidth=2, label=f'Second ImEt Mean: {mean_second_ImEt:.2f}')
plt.axvline(mean_third_ImEt, color='red', linestyle='dashed', linewidth=2, label=f'Third ImEt Mean: {mean_third_ImEt:.2f}')
plt.axvline(matching_ImEt_values[0], color='blue', linewidth=2)
plt.axvline(matching_ImEt_values[1], color='green', linewidth=2)
plt.axvline(matching_ImEt_values[2], color='red', linewidth=2)
plt.title('Histogram of First Three ImEt Values, first')
plt.xlabel('ImEt')
plt.ylabel('Frequency')





plt.show()

# %%
#first run, all three cffs. 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
fig_width = 3.385
fig_height = 2.75 
fontsize = 11 
fontfamily = 'sans-serif' 

#Reading in the true values, called dff
def normalize(QQ, xB, t):
    QQ_norm = -1 + 2 * (QQ / 10) 
    xB_norm = -1 + 2 * (xB / 0.8)
    t_norm = -1 + 2 * ((t + 2) / 2 )
    return QQ_norm, xB_norm, t_norm  

datafilee = "8shorttA.csv" 
def get_data():
    df = pd.read_csv(datafilee, dtype=np.float32)
    return df
def filter_unique_sets(df):
    # Drop duplicate rows based on the first column
    unique_rows = df.drop_duplicates(subset=df.columns[0])
    return unique_rows 
dff = filter_unique_sets(get_data())
dff = dff[['ReH', 'ReE', 'ReHt', 'ReEt','ImH', 'ImE', 'ImHt', 'ImEt', 'QQ', 'xB', 't']]

QQQ, xbb, tt = dff['QQ'], dff['xB'], dff['t']
QQQ, xbb, tt = normalize(QQQ, xbb, tt)
dff['QQ'], dff['xB'], dff['t'] = QQQ, xbb, tt

#the resutls and plotting 
df = pd.read_csv('8_fulllT2.csv')
# Remove rows with string values in any column
df = df.apply(pd.to_numeric, errors='coerce').dropna()

# Group the DataFrame by 'QQ', 'x_B', and 't', and then calculate the mean and standard deviation of 'ReH', 'ReE', and 'ReHt'
grouped_df = df.groupby(['QQ', 'x_B', 't'])[['ReH_results', 'ReE_results', 'ReHt_results']].agg(['mean', 'std']).reset_index()

# Extract the required columns
QQ = grouped_df['QQ'].values
x_B = grouped_df['x_B'].values
t = grouped_df['t'].values
ReH_mean = grouped_df[('ReH_results', 'mean')].values
ReH_std = grouped_df[('ReH_results', 'std')].values
ReE_mean = grouped_df[('ReE_results', 'mean')].values
ReE_std = grouped_df[('ReE_results', 'std')].values
ReHt_mean = grouped_df[('ReHt_results', 'mean')].values
ReHt_std = grouped_df[('ReHt_results', 'std')].values 
# Group the DataFrame by 'QQ', 'x_B', and 't', and then calculate the mean and standard deviation of 'ReEt', 'ImH', and 'ImE'
grouped_df = df.groupby(['QQ', 'x_B', 't'])[['ReEt_results', 'ImH_results', 'ImE_results']].agg(['mean', 'std']).reset_index()
ReEt_mean = grouped_df[('ReEt_results', 'mean')].values
ReEt_std = grouped_df[('ReEt_results', 'std')].values
ImH_mean = grouped_df[('ImH_results', 'mean')].values
ImH_std = grouped_df[('ImH_results', 'std')].values
ImE_mean = grouped_df[('ImE_results', 'mean')].values
ImE_std = grouped_df[('ImE_results', 'std')].values   
# Group the DataFrame by 'QQ', 'x_B', and 't', and then calculate the mean and standard deviation of 'ImHt' and 'ImEt'
grouped_df = df.groupby(['QQ', 'x_B', 't'])[['ImHt_results', 'ImEt_results']].agg(['mean', 'std']).reset_index() 
ImHt_mean = grouped_df[('ImHt_results', 'mean')].values
ImHt_std = grouped_df[('ImHt_results', 'std')].values
ImEt_mean = grouped_df[('ImEt_results', 'mean')].values
ImEt_std = grouped_df[('ImEt_results', 'std')].values

# Create a function to generate scatter plots
def create_scatter_plot(x, y, yerr, xlabel, ylabel, title, filename, True_y):
    plt.figure(figsize=(10, 6))
    plt.errorbar(x, y, yerr=yerr, fmt='o', ecolor='r', capsize=5, linestyle='None', marker='o')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(True)
    plt.scatter(x, True_y, color = 'orange')
    #plt.savefig(filename)
    plt.show()

# Generate scatter plots for ReH, ReE, and ReHt with QQ as the x-axis
create_scatter_plot(QQ, ReH_mean, ReH_std, 'QQ', 'Average ReH', 'Scatter Plot of ReH vs QQ with Error Bars', 'scatter_plot_ReH_QQ.png', dff['ReH'])
create_scatter_plot(QQ, ReE_mean, ReE_std, 'QQ', 'Average ReE', 'Scatter Plot of ReE vs QQ with Error Bars', 'scatter_plot_ReE_QQ.png', dff['ReE'])
create_scatter_plot(QQ, ReHt_mean, ReHt_std, 'QQ', 'Average ReHt', 'Scatter Plot of ReHt vs QQ with Error Bars', 'scatter_plot_ReHt_QQ.png', dff['ReHt'])
# Generate scatter plots for ReEt, ImH, and ImE with QQ as the x-axis
create_scatter_plot(QQ, ReEt_mean, ReEt_std, 'QQ', 'Average ReEt', 'Scatter Plot of ReEt vs QQ with Error Bars', 'scatter_plot_ReEt_QQ.png', dff['ReEt'])
create_scatter_plot(QQ, ImH_mean, ImH_std, 'QQ', 'Average ImH', 'Scatter Plot of ImH vs QQ with Error Bars', 'scatter_plot_ImH_QQ.png', dff['ImH'])
create_scatter_plot(QQ, ImE_mean, ImE_std, 'QQ', 'Average ImE', 'Scatter Plot of ImE vs QQ with Error Bars', 'scatter_plot_ImE_QQ.png', dff['ImE'])
# Generate scatter plots for ImHt and ImEt with QQ as the x-axis
create_scatter_plot(QQ, ImHt_mean, ImHt_std, 'QQ', 'Average ImHt', 'Scatter Plot of ImHt vs QQ with Error Bars', 'scatter_plot_ImHt_QQ.png', dff['ImHt'])
create_scatter_plot(QQ, ImEt_mean, ImEt_std, 'QQ', 'Average ImEt', 'Scatter Plot of ImEt vs QQ with Error Bars', 'scatter_plot_ImEt_QQ.png', dff['ImEt'])

print()


# Generate scatter plots for ReH, ReE, and ReHt with x_B as the x-axis
create_scatter_plot(x_B, ReH_mean, ReH_std, 'x_B', 'Average ReH', 'Scatter Plot of ReH vs x_B with Error Bars', 'scatter_plot_ReH_x_B.png', dff['ReH'])
create_scatter_plot(x_B, ReE_mean, ReE_std, 'x_B', 'Average ReE', 'Scatter Plot of ReE vs x_B with Error Bars', 'scatter_plot_ReE_x_B.png', dff['ReE'])
create_scatter_plot(x_B, ReHt_mean, ReHt_std, 'x_B', 'Average ReHt', 'Scatter Plot of ReHt vs x_B with Error Bars', 'scatter_plot_ReHt_x_B.png', dff['ReHt'])
# Generate scatter plots for ReEt, ImH, and ImE with x_B as the x-axis
create_scatter_plot(x_B, ReEt_mean, ReEt_std, 'x_B', 'Average ReEt', 'Scatter Plot of ReEt vs x_B with Error Bars', 'scatter_plot_ReEt_x_B.png', dff['ReEt'])
create_scatter_plot(x_B, ImH_mean, ImH_std, 'x_B', 'Average ImH', 'Scatter Plot of ImH vs x_B with Error Bars', 'scatter_plot_ImH_x_B.png', dff['ImH'])
create_scatter_plot(x_B, ImE_mean, ImE_std, 'x_B', 'Average ImE', 'Scatter Plot of ImE vs x_B with Error Bars', 'scatter_plot_ImE_x_B.png', dff['ImE'])
# Generate scatter plots for ImHt and ImEt with x_B as the x-axis
create_scatter_plot(x_B, ImHt_mean, ImHt_std, 'x_B', 'Average ImHt', 'Scatter Plot of ImHt vs x_B with Error Bars', 'scatter_plot_ImHt_x_B.png', dff['ImHt'])
create_scatter_plot(x_B, ImEt_mean, ImEt_std, 'x_B', 'Average ImEt', 'Scatter Plot of ImEt vs x_B with Error Bars', 'scatter_plot_ImEt_x_B.png', dff['ImEt'])

print()




# Generate scatter plots for ReH, ReE, and ReHt with t as the x-axis
create_scatter_plot(t, ReH_mean, ReH_std, 't', 'Average ReH', 'Scatter Plot of ReH vs t with Error Bars', 'scatter_plot_ReH_t.png', dff['ReH'])
create_scatter_plot(t, ReE_mean, ReE_std, 't', 'Average ReE', 'Scatter Plot of ReE vs t with Error Bars', 'scatter_plot_ReE_t.png', dff['ReE'])
create_scatter_plot(t, ReHt_mean, ReHt_std, 't', 'Average ReHt', 'Scatter Plot of ReHt vs t with Error Bars', 'scatter_plot_ReHt_t.png', dff['ReHt'])
# Generate scatter plots for ReEt, ImH, and ImE with t as the x-axis
create_scatter_plot(t, ReEt_mean, ReEt_std, 't', 'Average ReEt', 'Scatter Plot of ReEt vs t with Error Bars', 'scatter_plot_ReEt_t.png', dff['ReEt'])
create_scatter_plot(t, ImH_mean, ImH_std, 't', 'Average ImH', 'Scatter Plot of ImH vs t with Error Bars', 'scatter_plot_ImH_t.png', dff['ImH'])
create_scatter_plot(t, ImE_mean, ImE_std, 't', 'Average ImE', 'Scatter Plot of ImE vs t with Error Bars', 'scatter_plot_ImE_t.png', dff['ImE'])
# Generate scatter plots for ImHt and ImEt with t as the x-axis
create_scatter_plot(t, ImHt_mean, ImHt_std, 't', 'Average ImHt', 'Scatter Plot of ImHt vs t with Error Bars', 'scatter_plot_ImHt_t.png', dff['ImHt'])
create_scatter_plot(t, ImEt_mean, ImEt_std, 't', 'Average ImEt', 'Scatter Plot of ImEt vs t with Error Bars', 'scatter_plot_ImEt_t.png', dff['ImEt'])
# Out:
# /tmp/ipykernel_777033/1172907985.py:68: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(x, y, yerr=yerr, fmt='o', ecolor='r', capsize=5, linestyle='None', marker='o')
